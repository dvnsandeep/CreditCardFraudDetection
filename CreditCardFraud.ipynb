# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

# %%
df = pd.read_csv('/kaggle/input/creditcardfraud/creditcard.csv')

# %%
df = df.sample(frac=0.1,random_state=20)

# %%
df.shape

# %%
df.columns

# %%
df.iloc

# %%
neg=df[df['Class']==1].size
pos=df[df['Class']==0].size

# %%
df.isna().sum()

# %%
X = df.drop(columns='Class',axis=1)

# %%
Y = df['Class'].values

# %%
from matplotlib import pyplot as pltfrom
import matplotlib.pyplot as plt
plt.bar(["not fraud","fraud"],[pos,neg])

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
   # X is the feature set and y is the target
for train_index, val_index in skf.split(X,Y):
    print("Train:", train_index, "Validation:", val_index)
    X_train, X_test = X.iloc[train_index], X.iloc[val_index]
    y_train, y_test = Y[train_index], Y[val_index]

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)

# %%
X_test = sc.fit_transform(X_test)

# %%
description = df.describe()
print(description)

# %%
print(df.shape)

# %%
print(df.head(3))

# %%
print(df.groupby('Class').describe())

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
d = np.random.randint(1,100,10)

# %%
e = np.random.randint(10,200,10)

# %%
plt.scatter(df['V1'],df['V2'])

# %%
df.hist()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 200, criterion = 'gini', random_state = 48)

# %%
classifier.fit(X_train,y_train)

# %%
ypred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, ypred)
print(cm)

# %%
from sklearn.metrics import classification_report, accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef

# %%
acc = accuracy_score(y_test,ypred)
print(acc)

# %%
pres = precision_score(y_test,ypred)
print(pres)

# %%
rec = recall_score(y_test,ypred)
rec

# %%
f1s = f1_score(y_test,ypred)
print(f1s)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier1 = KNeighborsClassifier(n_neighbors = 2,leaf_size=10)
classifier1.fit(X_train, y_train)

# %%
ypred1 = classifier1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, ypred1)
print(cm)

# %%
ac1 = accuracy_score(y_test,ypred1)
rc1 = recall_score(y_test,ypred1)

print(ac1)
print(rc1)

# %%
dif_k = [2,3,4,5,6,7,8]
correct_pred = list()
for k in dif_k:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    cm = confusion_matrix(y_test,y_pred)
    correct_pred.append(cm[0][0]+cm[1][1])
plt.plot(dif_k,correct_pred)

plt.xlabel('Different K values')
plt.ylabel('No. of Correct Predictions')

plt.title('Performance')

plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt

max_auc = -1

l = [1,3,5,7,9,11,15]

for k in l:
    classifier = KNeighborsClassifier(n_neighbors=k)
    classifier.fit(X_train, y_train)
    y_pred =classifier.predict_proba(X_test)
    fpr, tpr, threshold = roc_curve(y_test, y_pred[:, 1])
    
    

#From the above, the ROC AUC score can be computed as
    roc_auc = auc(fpr, tpr)
    print("Method 1 \nroc_auc = auc(fpr, tpr) \nRoc_Auc score = "+str(roc_auc))

    print()
# or directly using roc_auc_score() method of sklearn:

    roc_auc = roc_auc_score(y_test, y_pred[:, 1])
    print("Method 2\nroc_auc = roc_auc_score(y_test, y_pred[:, 1]) \nRoc_Auc score = "+str(roc_auc))

    if(roc_auc> max_auc):
        max_auc = roc_auc
        maxk = k
# We can also plot the ROC curves for different models using matplotlib:

    plt.style.use('seaborn')
    
    plt.plot([0, 1], [0, 1],'r--',label = 'Diagonal')
    plt.xlim([-0.01,1.01])
    plt.ylim([0, 1.1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.title("For K = " + str(k))
    
    
#Set baseline model as diagonal
    # y label
    # x label
   
    plt.plot(fpr, tpr, linestyle='--', label = 'AUC = %0.2f' %roc_auc) # plot roc curves
    plt.legend(loc = 'lower right')
    plt.show();

    
print("After interpreting the results, the kNN model with k-value = "+str(maxk)+" has the max area under curve\nauc="+str(max_auc))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
classifier2 = LogisticRegression()

# %%
classifier2.fit(X_train,y_train)

# %%
ypred2 = classifier2.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, ypred2)
print(cm)

# %%
ac2 = accuracy_score(y_test,ypred2)
rc2 = recall_score(y_test,ypred2)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier3 = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier3.fit(X_train,y_train)

# %%
ypred3 = classifier3.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, ypred3)
print(cm)

# %%
ac3 = accuracy_score(y_test,ypred3)
rc3 = recall_score(y_test,ypred3)

# %%
from sklearn.svm import SVC

# %%
classifier4 = SVC()

# %%
classifier4.fit(X_train,y_train)

# %%
ypred4 = classifier4.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, ypred4)
print(cm)

# %%
ac4 = accuracy_score(y_test,ypred4)
rc4 = recall_score(y_test,ypred4)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
scores1 = []
scores2 = []
scores3 = []
scores4 = []
classifier1 = KNeighborsClassifier(n_neighbors = 4)
classifier2 = LogisticRegression()
classifier3 = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier4 = SVC()
cv = KFold(n_splits=5, random_state=42, shuffle=False)
for train_index, test_index in cv.split(X,Y):
    print("Train Index: ", train_index, "\n")
    print("Test Index: ", test_index)

    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = Y[train_index], Y[test_index]
    classifier1.fit(X_train, y_train)
    classifier2.fit(X_train, y_train)
    classifier3.fit(X_train, y_train)
    classifier4.fit(X_train, y_train)
    scores1.append(classifier1.score(X_test, y_test))
    scores2.append(classifier2.score(X_test, y_test))
    scores3.append(classifier3.score(X_test, y_test))
    scores4.append(classifier4.score(X_test, y_test))


print(scores1)
print(scores2)
print(scores3)
print(scores4)

# %%
cname = ['Knn','Logistic','DecisionTree','SVC']

scores = [(sum(scores1)/len(scores1)) , (sum(scores2)/len(scores2)) , (sum(scores3)/len(scores3)),(sum(scores4)/len(scores4))]

# %%
from matplotlib import pyplot as pltfrom
plt.bar(cname,scores)

# %%
crec=[rec,rc1,rc2,rc3,rc4]
cname = ["Random Forest",'Knn','Logistic','DecisionTree','SVC']
plt.bar(cname,crec)
